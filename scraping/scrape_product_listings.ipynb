# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
import requests

cookies = {
    'user_uuid': 'ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P',
    'mynt-eupv': '1',
    'ru': 'OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8',
    'at': '...',
    '_d_id': 'cfdb5d60-a759-47dd-8d8c-71d8a1d3ea32',
    'mynt-ulc-api': 'pincode%3A110002',
    'x-mynt-pca': 'Z5b7rOVKRpSTMocAcIpr6fyo70CmZ0DlUHBOBnb_BqRjv74sgehS4VqJ_4yXqR6VxDSfIPqA0mQ9BpWUMhG2ufqkM10-IkR0Xt0ub_hLrybflCAXbWNoLqB0cNtM3gSZHtni5-tMdYBnQwDfybAmCNG6Nn90Dcn6qgap_UxO8walGyk8m4UL0A%3D%3D',
    '_ma_session': '%7B%22id%22%3A%228b950e97-91d3-467b-a017-1b9e53ae5b07-cfdb5d60-a759-47dd-8d8c-71d8a1d3ea32%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D',
    '_mxab_': 'config.bucket%3Dregular%3Bcoupon.cart.channelAware%3DchannelAware_Enabled%3Bcart.cartfiller.personalised%3Denabled',
    '_pv': 'default',
    'dp': 'd',
    'microsessid': '966',
    'lt_timeout': '1',
    'lt_session': '1',
    '_xsrf': 'HGv7kdeuf5WtKk8doFu7iwmV2YSdbqrS',
    'mynt-loc-src': 'expiry%3A1769835944866%7Csource%3AIP',
    'bm_mi': '1A53C1258B157FCAD2B508FDC7DD6875~~1',
    '_abck': 'D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAF%2f%2f%2f%2f%2fysv0cn1SEJooFsFucDFVuh4aZuYcgKVlnn9PDDDDcp3pQ8gFhxkBmHfOlmsh8Mt8NwxeXEEW+DBSUmLIL%2fH4NAc812GIAqvTEJ%2fBcJqdWrKgIGs%2fFuvsNk%2fqHT0ioj7Wc4GLG4%3d~-1',
    'bm_sz': 'D7FA70C36428A98D2FE1F6EEF24E4209~...~3486771~4404793',
    'utm_track_v1': '%7B%22utm_source%22%3A%22direct%22%2C%22utm_medium%22%3A%22direct%22%2C%22trackstart%22%3A1769834628%2C%22trackend%22%3A1769834688%7D',
    'user_session': '0cyvl3nMpgIygc_u2rwtOw.7XUTfUZNJ8XBoN-JwuknhGa_-CfnDIOXxcnOPbQwxd_ujczSXsq-viZNZnB3r8fWT05YQpUQ_BHJPlvirGw3hxMBLIx_WPzT5srL0X6Dxx9VSxzVExXcy54Rll-fS0ES1EK0B4iULMFgHrnUleAEBw.1769834504576.86400000.glufYWwh61Rbk4SVJTvF0M4RxLZKe3RESoXQ585ZBsg',
    'ak_bmsc': '861AE4157F6FD95C5F5C1F0F4EA1F4F6~000000000000000000000000000000~...',
    'utrid': 'YkoBDFoCVQNOB29zFFZAMCM3MjA3NDc3NyQy.db8697a21868c4cfaec1aefd7935a290',
    'bm_sv': '255B70A48F18D260A933194A49BAADC6~~1',
}

headers = {
    'accept': 'application/json',
    'accept-language': 'en-US,en;q=0.6',
    'app': 'web',
    'content-type': 'application/json',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMwNjIwNzEiLCJhcCI6IjcxODQwNzY0MyIsImlkIjoiMjZlNTEwY2UwM2Y5ZmM1OSIsInRyIjoiMWQxMzBlMDk3YzI3ZTcyZDNlOWFhMWE2ZGRhNDNlZGMiLCJ0aSI6MTc2OTgzNDYzNjc3NSwidGsiOiI2Mjk1Mjg2In19',
    'pagination-context': '{"refresh":true,"v":1}',
    'priority': 'u=1, i',
    'referer': 'https://www.myntra.com/dresses?sort=recommended&f=Gender%3Amen%20women%2Cwomen',
    'sec-ch-ua': '"Not(A:Brand";v="8", "Chromium";v="144", "Brave";v="144"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'traceparent': '00-1d130e097c27e72d3e9aa1a6dda43edc-26e510ce03f9fc59-01',
    'tracestate': '6295286@nr=0-1-3062071-718407643-26e510ce03f9fc59----1769834636775',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36',
    'x-location-context': 'pincode=110002;source=IP',
    'x-meta-app': 'channel=web',
    'x-myntra-app': 'deviceID=cfdb5d60-a759-47dd-8d8c-71d8a1d3ea32;customerID=;reqChannel=web;appFamily=MyntraRetailWeb;',
    'x-myntraweb': 'Yes',
    'x-requested-with': 'browser',
    # 'cookie': 'user_uuid=ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P; mynt-eupv=1; ru=OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8; at=...; _d_id=cfdb5d60-a759-47dd-8d8c-71d8a1d3ea32; mynt-ulc-api=pincode%3A110002; x-mynt-pca=Z5b7rOVKRpSTMocAcIpr6fyo70CmZ0DlUHBOBnb_BqRjv74sgehS4VqJ_4yXqR6VxDSfIPqA0mQ9BpWUMhG2ufqkM10-IkR0Xt0ub_hLrybflCAXbWNoLqB0cNtM3gSZHtni5-tMdYBnQwDfybAmCNG6Nn90Dcn6qgap_UxO8walGyk8m4UL0A%3D%3D; _ma_session=%7B%22id%22%3A%228b950e97-91d3-467b-a017-1b9e53ae5b07-cfdb5d60-a759-47dd-8d8c-71d8a1d3ea32%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D; _mxab_=config.bucket%3Dregular%3Bcoupon.cart.channelAware%3DchannelAware_Enabled%3Bcart.cartfiller.personalised%3Denabled; _pv=default; dp=d; microsessid=966; lt_timeout=1; lt_session=1; _xsrf=HGv7kdeuf5WtKk8doFu7iwmV2YSdbqrS; mynt-loc-src=expiry%3A1769835944866%7Csource%3AIP; bm_mi=1A53C1258B157FCAD2B508FDC7DD6875~~1; _abck=D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAF%2f%2f%2f%2f%2fysv0cn1SEJooFsFucDFVuh4aZuYcgKVlnn9PDDDDcp3pQ8gFhxkBmHfOlmsh8Mt8NwxeXEEW+DBSUmLIL%2fH4NAc812GIAqvTEJ%2fBcJqdWrKgIGs%2fFuvsNk%2fqHT0ioj7Wc4GLG4%3d~-1; bm_sz=D7FA70C36428A98D2FE1F6EEF24E4209~...~3486771~4404793; utm_track_v1=%7B%22utm_source%22%3A%22direct%22%2C%22utm_medium%22%3A%22direct%22%2C%22trackstart%22%3A1769834628%2C%22trackend%22%3A1769834688%7D; user_session=0cyvl3nMpgIygc_u2rwtOw.7XUTfUZNJ8XBoN-JwuknhGa_-CfnDIOXxcnOPbQwxd_ujczSXsq-viZNZnB3r8fWT05YQpUQ_BHJPlvirGw3hxMBLIx_WPzT5srL0X6Dxx9VSxzVExXcy54Rll-fS0ES1EK0B4iULMFgHrnUleAEBw.1769834504576.86400000.glufYWwh61Rbk4SVJTvF0M4RxLZKe3RESoXQ585ZBsg; ak_bmsc=861AE4157F6FD95C5F5C1F0F4EA1F4F6~000000000000000000000000000000~...; utrid=YkoBDFoCVQNOB29zFFZAMCM3MjA3NDc3NyQy.db8697a21868c4cfaec1aefd7935a290; bm_sv=255B70A48F18D260A933194A49BAADC6~~1',
}

params = {
    'sort': 'recommended',
    'f': 'Gender:men women,women',
    'rows': '50',
    'o': '0',
    'plaEnabled': 'true',
    'xdEnabled': 'false',
    'isFacet': 'true',
    'p': '1',
    'pincode': '110002',
}

response = requests.get('https://www.myntra.com/gateway/v4/search/dresses', params=params, cookies=cookies, headers=headers)

# %%
from datetime import date

data = response.json()
products = data.get("products", [])

snapshot_date = date.today().isoformat()
extracted_items = []

#loop through the products and extract features
for p in products:
    if not isinstance(p, dict):
        continue
    ALLOWED = {
        "Crazy_Deal",
        "Festive_Price_Crash",
        "GST_Benefit_Included",
        "Myntra_Unique"
        }

    tag_groups = p.get("styleTagEntry", {}).get("tagGroups", {})

    promotion_tags = [
        t["tagId"]
        for block in ("pricing", "selection")
        for t in tag_groups.get(block, {}).get("tagInfos", [])
        if t.get("tagId") in ALLOWED
        ]
    extracted_items.append({
        "product_id": p.get("productId"),
        "brand": p.get("brand"),
        "gender": p.get('gender'),
        "category": p.get("category"),
        "master_category": (p.get("masterCategory") or {}).get('typeName'),
        "sub_category": (p.get('subCategory') or {}).get('typeName'),
        "article_type": (p.get("articleType") or {}).get('typeName'),
        "mrp": p.get("mrp"),
        "price": p.get("price"),
        "discount": p.get("discount"),
        "discount_type": p.get("discountType"),
        "discount_display_label": p.get("discountDisplayLabel"),
        #"coupon_data" = p.get("couponData") or {},
        "coupon_discount" : (p.get("couponData") or {}).get("couponDiscount"),
        "best_price": ((p.get("couponData") or {}).get("couponDescription") or {}).get("bestPrice"),
        "rating": p.get("rating"),
        "rating_count": p.get("ratingCount"),
        "list_views": p.get("listViews"),
        "inventory": sum(i.get("inventory", 0) for i in p.get("inventoryInfo", [])),
        "available": any(i.get("available", False) for i in p.get("inventoryInfo", [])),
        "sizes": p.get("sizes"),
        "has_multiple_sizes": p.get("hasMultipleSizes"),
        "snapshot_date": snapshot_date,
        "season": p.get("season"),
        "is_fast_fashion": p.get("isFastFashion"),
        "promotion_tags": "|".join(promotion_tags),
        "has_promotion": bool(promotion_tags),
        "year": p.get('year'),
        "preferred_delivery_tag": p.get("preferredDeliveryTag"),
        "delivery_promise": p.get("deliveryPromise"),
        "source_sort":"recommended"
    })

# %%
dff = pd.DataFrame(extracted_items)
print(dff.shape)
dff.tail()
# Out:
# (50, 30)
#     product_id                brand gender        category master_category  \
# 45    30685223            StyleCast  Women         Dresses         Apparel
# 46    32811098               KALINI  Women  Ethnic Dresses         Apparel
# 47    31055851           StyleStone  Women         Dresses         Apparel
# 48    28244954            StyleCast  Women         Dresses         Apparel
# 49    31831462  StyleCast x Revolte  Women         Dresses         Apparel
#
#    sub_category    article_type   mrp  price  discount discount_type  \
# 45        Dress         Dresses  1299    571       728             1
# 46        Dress  Ethnic Dresses  7999   1199      6800             1
# 47        Dress         Dresses  2599   1299      1300             1
# 48        Dress         Dresses  3149   1259      1890             1
# 49        Dress         Dresses  3799   1443      2356             1
#
#    discount_display_label  coupon_discount  best_price    rating  \
# ...

# %%
#Concatenate new page data to old page data
import os
day = 'day_20'

FILE_PATH = f'/home/manju/projects/ecommerce_product_scraping/data/raw/{day}.csv'

if os.path.exists(FILE_PATH):
    old_df = pd.read_csv(FILE_PATH)
    final_df = pd.concat([old_df, dff], ignore_index=True)
else:
    final_df = dff

final_df.to_csv(FILE_PATH, index=False)

print("Total rows so far:", final_df.shape[0])
# Out:
# Total rows so far: 2997

# %%
# #Concatenate discount, popular and recommended products file for every day
# day = "day5"
# df_disc = pd.read_csv(f'../data/raw/{day}_disc.csv')
# df_pop = pd.read_csv(f'../data/raw/{day}_pop.csv')
# df_reco = pd.read_csv(f'../data/raw/{day}_rec.csv')

# #adding sort column
# df_reco["source_sort"] = "recommended"
# df_pop["source_sort"] = "popularity"
# df_disc["source_sort"] = "discount"

# df_day_raw = pd.concat([df_pop, df_reco, df_disc], ignore_index=True)
# print(df_day_raw.shape)
# df_day_raw.head()

# %%
# #drop_duplicates
# df_day = df_day_raw.drop_duplicates(subset=['product_id', 'snapshot_date'])
# print(df_day.shape)
# df_day.head()

# %%
# #store in csv file
# day = "day_06"
# df_day_raw.to_csv(f'../data/raw/{day}.csv')
